# %%
#Install pygsheets
import requests # get connection
import pandas as pd
import json
import pygsheets
#from sqlalchemy import create_engine
#import sqlite3 as db

## NY Lottery API JSON Feed for Mega Millions
base_url = 'https://data.ny.gov/resource/5xaw-6ayf.json'
mega_millions1 = requests.get(base_url).json()
#mega_millions1

mega_millions1_df = pd.json_normalize(mega_millions1)
#mega_millions1_df.head(3)
#mega_millions1_df.info()
#mega_millions1_df.describe()

# Export to CSV
mega_millions1_df.to_csv('mega_millions1.csv')

# Creates and/or connects to SQLite DB Named lotto_results1.db
connection = db.connect(r'P:\Luke Barosso Python\db_house\lotto_results1.db')

#Appends the above DF to the DB Created into a table named mega_millions1_df
mega_millions1_df.to_sql(name="mega_millions1_df", con=connection, if_exists='append', index=False)

## Commit connection
connection.commit()
