# %%
pets = ['dog','cat','monkey','fish','snake']

#print(pets)

for pet in pets:
    print(pet)
    
for pet in enumerate(pets):
    print(pet)
# Out:
# dog
# cat
# monkey
# fish
# snake
# (0, 'dog')
# (1, 'cat')
# (2, 'monkey')
# (3, 'fish')
# (4, 'snake')

# %%
# Python3 code to iterate over a list
list = [1, 3, 5, 7, 9]
   
# Using enumerate() 
#for i, val in enumerate(list):
    #print (i, ",",val)
    
for lis in enumerate(list):
    print(lis)
# Out:
# (0, 1)
# (1, 3)
# (2, 5)
# (3, 7)
# (4, 9)
